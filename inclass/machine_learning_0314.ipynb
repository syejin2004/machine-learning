# %% [markdown]
# <a href="https://colab.research.google.com/github/syejin2004/machine-learning/blob/main/inclass/machine_learning_0314.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 기계학습 실습

# %% [markdown]
# ### 산점도 시각화 및 사이킷런을 이용한 선형 모델 훈련과 예측

# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression

data_root = "https://github.com/ageron/data/raw/main/"
lifesat = pd.read_csv(data_root + "lifesat/lifesat.csv")
X = lifesat[["GDP per capita (USD)"]].values
y = lifesat["Life satisfaction"].values

lifesat.plot(kind='scatter', grid=True,
             x="GDP per capita (USD)", y="Life satisfaction")
plt.axis([23_500, 62_500, 4, 9])
plt.show()

model = LinearRegression()

model.fit(X, y)

X_new = [[37_655.2]]
print(model.predict(X_new))
# Out:
# [6.30165767]

# %% [markdown]
# ### 택시요금 예측과 선형 데이터를 통한 머신러닝 문제

# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression

lifesat = pd.read_csv("data.csv")
X = lifesat[["dist"]].values
y = lifesat[["won"]].values

lifesat.plot(kind="scatter", grid=True, x="dist", y="won")
plt.axis([0, 12, 0, 35000])
plt.show()

model = LinearRegression()

model.fit(X, y)

X_new = [[8]]
print(model.predict(X_new))
# Out:
# [[14233.40143003]]

# %% [markdown]
# ### 시험점수 예측과 선형 데이터를 통한 머신러닝 문제

# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression

lifesat = pd.read_csv("score.csv")
X = lifesat[["time"]].values
y = lifesat[["score"]].values

lifesat.plot(kind="scatter", grid=True, x="time", y="score")
plt.axis([0, 10, 50, 100])
plt.show()

model = LinearRegression()

model.fit(X, y)

X_new = [[7.5]]
print(model.predict(X_new))
# Out:
# [[92.33579915]]
